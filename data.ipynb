# %% [markdown]
# # [⚡ Open in Google Sheets](https://docs.google.com/spreadsheets/d/1_YdUFRJF4nxg8Ar_-Trj-4ldqCe3I7xQuE9tmadlmlc/edit)
# ---

# %% [markdown]
# ### 📊 Spreadsheet Preview
# <table border="1" style="border-collapse: collapse; width: 100%; font-family: sans-serif;"><tr><th style="background-color: #f2f2f2; padding: 8px; border: 1px solid #ddd; text-align: left; font-weight: bold;">Learning</th><th style="background-color: #f2f2f2; padding: 8px; border: 1px solid #ddd; text-align: left; font-weight: bold;"></th></tr><tr><td style="padding: 8px; border: 1px solid #ddd;"></td><td style="padding: 8px; border: 1px solid #ddd;">nodes</td></tr><tr><td style="padding: 8px; border: 1px solid #ddd;"></td><td style="padding: 8px; border: 1px solid #ddd;">neuron</td></tr><tr><td style="padding: 8px; border: 1px solid #ddd;"></td><td style="padding: 8px; border: 1px solid #ddd;">layer</td></tr><tr><td style="padding: 8px; border: 1px solid #ddd;"></td><td style="padding: 8px; border: 1px solid #ddd;">multilayer</td></tr></table>
